# %% [markdown]
# # Optical frames analysis

# %% [markdown]
# This code processes images from the optical frame camera (12-frame):
#
# To get started, run the code in the cell below:

# %%
# %matplotlib notebook
from SourceCode.OpticalFrames import *

# %% [markdown]
# Next, add the shot info, the interframe (in ns) and start time (in ns).
#
# Please ensure that background files are located in a subfolder "background" and shot files in the folder "shot"

# %%
shotName = "s1212_16"
interframe = 30
startTime = 1800

# %% [markdown]
# This next cell creates an object ('s') which stores the optical frame camera.

# %%
s=OpticalFrames(shotName,startTime,interframe)
# Out:
# Folder found: //LINNA/Users/Magpie/Documents/MAGPIE data/2016/dec_2016/s1212_16 Exploding Liner
# Optical frame folder found: s1212_16 fast frame
# Searching: //LINNA/Users/Magpie/Documents/MAGPIE data/2016/dec_2016/s1212_16 Exploding Liner/s1212_16 fast frame/shot
# Searching: //LINNA/Users/Magpie/Documents/MAGPIE data/2016/dec_2016/s1212_16 Exploding Liner/s1212_16 fast frame/shot

# %% [markdown]
# Now you have 's', you can display the images.
#
# s.plot(toPlot="shot", frame=n) plots frame n. The toPlot argument can take several forms:
# * "shot" = raw shot images
# * "background" = raw background images
# * "raw" = raw shot images
#
# The following functions may be used to plot a sequence of images.
# * s.plot_sequence() plots all frames
# * s.plot_sequence(frames=list(range(n,m))) plots frames n to m
# * s.plot_sequence(toPlot="shot", frames=list(range(n,m))) plots frames n to m with the same toPlot argument as above.

# %%
s.plot_sequence()
# Out:
# <img src="data:image/png;base64,...">
